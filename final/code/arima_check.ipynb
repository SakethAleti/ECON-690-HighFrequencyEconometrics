# %%
import pandas as pd
import numpy as np
from statsmodels.tsa import arima_process

# %%
pd.plotting.autocorrelation_plot(
    arima_process.arma_generate_sample([1, -0.5, -0.9, -0.1, -0.1, 0, 0, 0, -0.9], [1], nsample=100, scale=1, burnin=10)
)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>
