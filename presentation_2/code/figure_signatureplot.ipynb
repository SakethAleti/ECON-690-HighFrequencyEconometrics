# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.io
from tqdm.auto import tqdm

# %% [markdown]
# # Import Data

# %%
ticker_1s_df = pd.read_csv('../data/clean/ticker_1s.csv')

# %%
ticker_1s_df[['ticker', 'ticker_desc', 'ticker_desc_short', 'date', 'datetime', 'price']]
# Out:
#        ticker                          ticker_desc ticker_desc_short  \
# 0         IEF  iShares 7-10 Year Treasury Bond ETF         7-10 Year
# 1         IEF  iShares 7-10 Year Treasury Bond ETF         7-10 Year
# 2         IEF  iShares 7-10 Year Treasury Bond ETF         7-10 Year
# 3         IEF  iShares 7-10 Year Treasury Bond ETF         7-10 Year
# 4         IEF  iShares 7-10 Year Treasury Bond ETF         7-10 Year
# ...       ...                                  ...               ...
# 701959    TLT   iShares 20+ Year Treasury Bond ETF          20+ Year
# 701960    TLT   iShares 20+ Year Treasury Bond ETF          20+ Year
# 701961    TLT   iShares 20+ Year Treasury Bond ETF          20+ Year
# 701962    TLT   iShares 20+ Year Treasury Bond ETF          20+ Year
# 701963    TLT   iShares 20+ Year Treasury Bond ETF          20+ Year
#
#               date            datetime    price
# 0       2020-01-03 2020-01-03 09:30:00  111.150
# 1       2020-01-03 2020-01-03 09:30:01  111.150
# 2       2020-01-03 2020-01-03 09:30:02  111.150
# 3       2020-01-03 2020-01-03 09:30:03  111.150
# 4       2020-01-03 2020-01-03 09:30:04  111.150
# ...            ...                 ...      ...
# 701959  2020-08-19 2020-08-19 15:59:55  163.735
# 701960  2020-08-19 2020-08-19 15:59:56  163.745
# 701961  2020-08-19 2020-08-19 15:59:57  163.745
# 701962  2020-08-19 2020-08-19 15:59:58  163.750
# 701963  2020-08-19 2020-08-19 15:59:59  163.740
#
# [701964 rows x 6 columns]

# %% [markdown]
# # Process

# %%
# Add log price
ticker_1s_df['log_price'] = np.log(ticker_1s_df['price'])

# %%
def RV(returns):
    return np.sum(np.square(np.array(returns.dropna())))

# %%
ticker_s_df_dict = {}

# List of sample rates to consider (in seconds)
sec_samplerate_range = [1, 5, 10, 15, 30, 60, 120, 180]

# Create new dataframes for each sample rate
for sec_samplerate in tqdm(sec_samplerate_range):

    # Sample rate as string, passed to pd.Grouper
    sec_samplerate_str = str(sec_samplerate) + "s"

    # Create new dataframe with last log price every {sec_samplerate} seconds
    ticker_s_df = (
        ticker_1s_df.groupby(
            ["ticker", "ticker_desc", "date", pd.Grouper(key="datetime", freq=sec_samplerate_str)]
        )["log_price"]
        .last()
        .reset_index()
    )

    # Add log returns
    ticker_s_df["return"] = (
        ticker_s_df.sort_values(by=["datetime"])
        .groupby(["date", "ticker", "ticker_desc"])["log_price"]
        .diff(1)
    )
    
    # Add realized volatility for each day
    ticker_s_df['rv_1day'] = ticker_s_df.groupby(['ticker', 'ticker_desc', 'date'])['return'].transform(RV)

    # Save dataframe into dictionary
    ticker_s_df_dict[sec_samplerate_str] = ticker_s_df.copy()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
ticker_s_df_dict
# Out:
# {'1s':        ticker                          ticker_desc        date  \
#  0         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...       ...                                  ...         ...
#  701959    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  701960    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  701961    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  701962    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  701963    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                    datetime  log_price    return   rv_1day
#  0      2020-01-03 09:30:00   4.710881       NaN  0.000011
#  1      2020-01-03 09:30:01   4.710881  0.000000  0.000011
#  2      2020-01-03 09:30:02   4.710881  0.000000  0.000011
#  3      2020-01-03 09:30:03   4.710881  0.000000  0.000011
#  4      2020-01-03 09:30:04   4.710881  0.000000  0.000011
#  ...                    ...        ...       ...       ...
#  701959 2020-08-19 15:59:55   5.098249 -0.000031  0.000044
#  701960 2020-08-19 15:59:56   5.098310  0.000061  0.000044
#  701961 2020-08-19 15:59:57   5.098310  0.000000  0.000044
#  701962 2020-08-19 15:59:58   5.098341  0.000031  0.000044
#  701963 2020-08-19 15:59:59   5.098280 -0.000061  0.000044
#
#  [701964 rows x 7 columns],
#  '5s':        ticker                          ticker_desc        date  \
#  0         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4         IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...       ...                                  ...         ...
#  140391    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  140392    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  140393    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  140394    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  140395    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                    datetime  log_price    return   rv_1day
#  0      2020-01-03 09:30:00   4.710881       NaN  0.000016
#  1      2020-01-03 09:30:05   4.710971  0.000090  0.000016
#  2      2020-01-03 09:30:10   4.710971  0.000000  0.000016
#  3      2020-01-03 09:30:15   4.710881 -0.000090  0.000016
#  4      2020-01-03 09:30:20   4.710881  0.000000  0.000016
#  ...                    ...        ...       ...       ...
#  140391 2020-08-19 15:59:35   5.098219  0.000122  0.000044
#  140392 2020-08-19 15:59:40   5.098219  0.000000  0.000044
#  140393 2020-08-19 15:59:45   5.098280  0.000061  0.000044
#  140394 2020-08-19 15:59:50   5.098280  0.000000  0.000044
#  140395 2020-08-19 15:59:55   5.098280  0.000000  0.000044
#
#  [140396 rows x 7 columns],
#  '10s':       ticker                          ticker_desc        date  \
#  0        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...      ...                                  ...         ...
#  70195    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  70196    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  70197    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  70198    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  70199    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                   datetime  log_price    return   rv_1day
#  0     2020-01-03 09:30:00   4.710971       NaN  0.000007
#  1     2020-01-03 09:30:10   4.710881 -0.000090  0.000007
#  2     2020-01-03 09:30:20   4.710791 -0.000090  0.000007
#  3     2020-01-03 09:30:30   4.710701 -0.000090  0.000007
#  4     2020-01-03 09:30:40   4.710791  0.000090  0.000007
#  ...                   ...        ...       ...       ...
#  70195 2020-08-19 15:59:10   5.098158 -0.000122  0.000044
#  70196 2020-08-19 15:59:20   5.098158  0.000000  0.000044
#  70197 2020-08-19 15:59:30   5.098219  0.000061  0.000044
#  70198 2020-08-19 15:59:40   5.098280  0.000061  0.000044
#  70199 2020-08-19 15:59:50   5.098280  0.000000  0.000044
#
#  [70200 rows x 7 columns],
#  '15s':       ticker                          ticker_desc        date  \
#  0        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...      ...                                  ...         ...
#  46795    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  46796    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  46797    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  46798    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  46799    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                   datetime  log_price    return   rv_1day
#  0     2020-01-03 09:30:00   4.710971       NaN  0.000007
#  1     2020-01-03 09:30:15   4.710791 -0.000180  0.000007
#  2     2020-01-03 09:30:30   4.710791  0.000000  0.000007
#  3     2020-01-03 09:30:45   4.710791  0.000000  0.000007
#  4     2020-01-03 09:31:00   4.710611 -0.000180  0.000007
#  ...                   ...        ...       ...       ...
#  46795 2020-08-19 15:58:45   5.098341  0.000122  0.000044
#  46796 2020-08-19 15:59:00   5.098158 -0.000183  0.000044
#  46797 2020-08-19 15:59:15   5.098158  0.000000  0.000044
#  46798 2020-08-19 15:59:30   5.098219  0.000061  0.000044
#  46799 2020-08-19 15:59:45   5.098280  0.000061  0.000044
#
#  [46800 rows x 7 columns],
#  '30s':       ticker                          ticker_desc        date  \
#  0        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...      ...                                  ...         ...
#  23395    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  23396    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  23397    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  23398    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  23399    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                   datetime  log_price    return   rv_1day
#  0     2020-01-03 09:30:00   4.710791       NaN  0.000007
#  1     2020-01-03 09:30:30   4.710791  0.000000  0.000007
#  2     2020-01-03 09:31:00   4.710611 -0.000180  0.000007
#  3     2020-01-03 09:31:30   4.710611  0.000000  0.000007
#  4     2020-01-03 09:32:00   4.710521 -0.000090  0.000007
#  ...                   ...        ...       ...       ...
#  23395 2020-08-19 15:57:30   5.098035 -0.000092  0.000044
#  23396 2020-08-19 15:58:00   5.098097  0.000061  0.000044
#  23397 2020-08-19 15:58:30   5.098341  0.000244  0.000044
#  23398 2020-08-19 15:59:00   5.098158 -0.000183  0.000044
#  23399 2020-08-19 15:59:30   5.098280  0.000122  0.000044
#
#  [23400 rows x 7 columns],
#  '60s':       ticker                          ticker_desc        date  \
#  0        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4        IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...      ...                                  ...         ...
#  11695    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  11696    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  11697    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  11698    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  11699    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                   datetime  log_price    return   rv_1day
#  0     2020-01-03 09:30:00   4.710791       NaN  0.000006
#  1     2020-01-03 09:31:00   4.710611 -0.000180  0.000006
#  2     2020-01-03 09:32:00   4.710431 -0.000180  0.000006
#  3     2020-01-03 09:33:00   4.710611  0.000180  0.000006
#  4     2020-01-03 09:34:00   4.710611  0.000000  0.000006
#  ...                   ...        ...       ...       ...
#  11695 2020-08-19 15:55:00   5.098341 -0.000244  0.000048
#  11696 2020-08-19 15:56:00   5.098097 -0.000244  0.000048
#  11697 2020-08-19 15:57:00   5.098035 -0.000061  0.000048
#  11698 2020-08-19 15:58:00   5.098341  0.000305  0.000048
#  11699 2020-08-19 15:59:00   5.098280 -0.000061  0.000048
#
#  [11700 rows x 7 columns],
#  '120s':      ticker                          ticker_desc        date  \
#  0       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...     ...                                  ...         ...
#  5845    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  5846    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  5847    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  5848    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  5849    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                  datetime  log_price    return   rv_1day
#  0    2020-01-03 09:30:00   4.710611       NaN  0.000005
#  1    2020-01-03 09:32:00   4.710611  0.000000  0.000005
#  2    2020-01-03 09:34:00   4.710701  0.000090  0.000005
#  3    2020-01-03 09:36:00   4.710701  0.000000  0.000005
#  4    2020-01-03 09:38:00   4.710701  0.000000  0.000005
#  ...                  ...        ...       ...       ...
#  5845 2020-08-19 15:50:00   5.098982 -0.000275  0.000050
#  5846 2020-08-19 15:52:00   5.098677 -0.000305  0.000050
#  5847 2020-08-19 15:54:00   5.098341 -0.000336  0.000050
#  5848 2020-08-19 15:56:00   5.098035 -0.000305  0.000050
#  5849 2020-08-19 15:58:00   5.098280  0.000244  0.000050
#
#  [5850 rows x 7 columns],
#  '180s':      ticker                          ticker_desc        date  \
#  0       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  1       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  2       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  3       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  4       IEF  iShares 7-10 Year Treasury Bond ETF  2020-01-03
#  ...     ...                                  ...         ...
#  3895    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  3896    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  3897    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  3898    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#  3899    TLT   iShares 20+ Year Treasury Bond ETF  2020-08-19
#
#                  datetime  log_price    return   rv_1day
#  0    2020-01-03 09:30:00   4.710431       NaN  0.000005
#  1    2020-01-03 09:33:00   4.710701  0.000270  0.000005
#  2    2020-01-03 09:36:00   4.710611 -0.000090  0.000005
#  3    2020-01-03 09:39:00   4.710521 -0.000090  0.000005
#  4    2020-01-03 09:42:00   4.710251 -0.000270  0.000005
#  ...                  ...        ...       ...       ...
#  3895 2020-08-19 15:45:00   5.099012  0.000665  0.000044
#  3896 2020-08-19 15:48:00   5.099012  0.000000  0.000044
#  3897 2020-08-19 15:51:00   5.098677 -0.000336  0.000044
#  3898 2020-08-19 15:54:00   5.098097 -0.000580  0.000044
#  3899 2020-08-19 15:57:00   5.098280  0.000183  0.000044
#
#  [3900 rows x 7 columns]}

# %%
data_df = ticker_1s_df.query('ticker == "TLT"').copy()

# %%
data_df
# Out:
#        ticker                         ticker_desc ticker_desc_short  \
# 561564    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 561565    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 561566    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 561567    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 561568    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# ...       ...                                 ...               ...
# 701959    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 701960    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 701961    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 701962    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
# 701963    TLT  iShares 20+ Year Treasury Bond ETF          20+ Year
#
#               date             datetime    price  log_price    return
# 561564  2020-01-03  2020-01-03 09:30:00  138.250   4.929064  0.000000
# 561565  2020-01-03  2020-01-03 09:30:01  138.235   4.928955 -0.000109
# 561566  2020-01-03  2020-01-03 09:30:02  138.220   4.928847 -0.000109
# 561567  2020-01-03  2020-01-03 09:30:03  138.230   4.928919  0.000072
# 561568  2020-01-03  2020-01-03 09:30:04  138.250   4.929064  0.000145
# ...            ...                  ...      ...        ...       ...
# 701959  2020-08-19  2020-08-19 15:59:55  163.735   5.098249 -0.000031
# 701960  2020-08-19  2020-08-19 15:59:56  163.745   5.098310  0.000061
# 701961  2020-08-19  2020-08-19 15:59:57  163.745   5.098310  0.000000
# 701962  2020-08-19  2020-08-19 15:59:58  163.750   5.098341  0.000031
# 701963  2020-08-19  2020-08-19 15:59:59  163.740   5.098280 -0.000061
#
# [140400 rows x 8 columns]
